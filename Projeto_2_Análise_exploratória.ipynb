# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavolima007/python-data-science-course/blob/main/Projeto_2_An%C3%A1lise_explorat%C3%B3ria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Projeto 2 - DSA Python

# %%
# !pip install plotly plotly-express

# %%
import pandas as pd

caminho_arquivo_colab = 'dataset.csv'

# Use pd.read_csv para ler o arquivo
df = pd.read_csv(caminho_arquivo_colab)

# %%
# Para ver as primeiras 5 linhas
display(df.head())

# Para ver as últimas 5 linhas
display(df.tail())
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9700 entries, 0 to 9699
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9700 non-null   object
#  1   Data_Pedido   9700 non-null   object
#  2   ID_Cliente    9700 non-null   object
#  3   Segmento      9700 non-null   object
#  4   Pais          9700 non-null   object
#  5   Cidade        9700 non-null   object
#  6   Estado        9700 non-null   object
#  7   ID_Produto    9700 non-null   object
#  8   Categoria     9700 non-null   object
#  9   SubCategoria  9700 non-null   object
#  10  Valor_Venda   9700 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 833.7+ KB
# None

# %%
display(df.describe())
# Out:
#         Valor_Venda
# count   9700.000000
# mean     230.469892
# std      627.504252
# min        0.444000
# 25%       17.248000
# 50%       54.272000
# 75%      209.932500
# max    22638.480000

# %%
display(df.isnull().sum())
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Valor_Venda'], kde=True)
plt.title('Distribuição do Valor de Venda')
plt.xlabel('Valor de Venda')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ## Qual cidade teve maior valor de venda?

# %%
# Agrupar por cidade e somar o valor de venda
vendas_por_cidade = df.groupby('Cidade')['Valor_Venda'].sum()

# Encontrar a cidade com o maior valor de venda
cidade_maior_venda = vendas_por_cidade.idxmax()
maior_valor_venda = vendas_por_cidade.max()

print(f"A cidade com o maior valor de venda é: {cidade_maior_venda}")
print(f"O maior valor de venda total nessa cidade foi: {maior_valor_venda:.2f}")
# Out:
# A cidade com o maior valor de venda é: New York City
# O maior valor de venda total nessa cidade foi: 251749.22

# %% [markdown]
# ## Qual o total de vendas por data do pedido?

# %%
# Agrupar por data do pedido e somar o valor de venda
vendas_por_data = df.groupby('Data_Pedido')['Valor_Venda'].sum()

# Para visualizar o resultado (as primeiras datas e seus totais de venda)
print(vendas_por_data.head())

# Você pode visualizar o resultado completo se for necessário
# print(vendas_por_data)
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
# Name: Valor_Venda, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupar por data do pedido e somar o valor de venda (já fizemos isso, mas incluído aqui para contexto)
vendas_por_data = df.groupby('Data_Pedido')['Valor_Venda'].sum()

# Selecionar as N datas com maiores vendas (vamos pegar as 10 principais como exemplo)
top_datas_venda = vendas_por_data.sort_values(ascending=False).head(10)

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x=top_datas_venda.index, y=top_datas_venda.values, palette='viridis')
plt.title('Top 10 Datas com Maior Valor de Venda')
plt.xlabel('Data do Pedido')
plt.ylabel('Total de Vendas')
plt.xticks(rotation=45, ha='right') # Rotação para melhor legibilidade das datas
plt.tight_layout() # Ajusta o layout
plt.show()
# Out:
# <ipython-input-20-c30e932fa469>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_datas_venda.index, y=top_datas_venda.values, palette='viridis')

# %% [markdown]
# ## Qual o total de vendas por estado?

# %%
# ## Qual o total de vendas por estado?
# %%
# Agrupar por estado e somar o valor de venda
vendas_por_estado = df.groupby('Estado')['Valor_Venda'].sum()

# Para visualizar o resultado (os primeiros estados e seus totais de venda)
print("Total de vendas por estado (primeiros estados):")
print(vendas_por_estado.head())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ordenar os estados pelo total de vendas para melhor visualização no gráfico
vendas_por_estado_ordenado = vendas_por_estado.sort_values(ascending=False)

# Criar o gráfico de barras
plt.figure(figsize=(14, 8)) # Ajuste o tamanho se houver muitos estados
sns.barplot(x=vendas_por_estado_ordenado.index, y=vendas_por_estado_ordenado.values, palette='viridis')
plt.title('Total de Vendas por Estado')
plt.xlabel('Estado')
plt.ylabel('Total de Vendas')
plt.xticks(rotation=90, ha='center') # Rotação para melhor legibilidade dos nomes dos estados
plt.tight_layout() # Ajusta o layout
plt.show()
# Out:
# Total de vendas por estado (primeiros estados):
# Estado
# Alabama        19510.6400
# Arizona        35272.6570
# Arkansas       11673.8300
# California    442927.0975
# Colorado       31841.5980
# Name: Valor_Venda, dtype: float64
# <ipython-input-22-04595c863609>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=vendas_por_estado_ordenado.index, y=vendas_por_estado_ordenado.values, palette='viridis')

# %% [markdown]
# ## Quais são as 10 cidades com maior total de vendas?

# %%
# ## Quais são as 10 cidades com maior total de vendas?
# %%
# Agrupar por cidade e somar o valor de venda
vendas_por_cidade = df.groupby('Cidade')['Valor_Venda'].sum()

# Ordenar as cidades pelo total de vendas em ordem decrescente e selecionar as top 10
top_10_cidades_venda = vendas_por_cidade.sort_values(ascending=False).head(10)

# Para visualizar o resultado (as top 10 cidades e seus totais de venda)
print("Top 10 Cidades com Maior Valor de Venda:")
print(top_10_cidades_venda)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar o gráfico de barras para as top 10 cidades
plt.figure(figsize=(12, 7)) # Ajuste o tamanho conforme necessário
sns.barplot(x=top_10_cidades_venda.index, y=top_10_cidades_venda.values, palette='viridis')
plt.title('Top 10 Cidades com Maior Valor de Venda')
plt.xlabel('Cidade')
plt.ylabel('Total de Vendas')
plt.xticks(rotation=45, ha='right') # Rotação para melhor legibilidade dos nomes das cidades
plt.tight_layout() # Ajusta o layout
plt.show()
# Out:
# Top 10 Cidades com Maior Valor de Venda:
# Cidade
# New York City    251749.2190
# Los Angeles      171654.6330
# Seattle          114725.4780
# San Francisco    107489.9520
# Philadelphia     107197.8030
# Houston           61590.1868
# San Diego         47458.3790
# Chicago           46974.3430
# Jacksonville      44713.1830
# Detroit           42446.9440
# Name: Valor_Venda, dtype: float64
# <ipython-input-23-0c6bdc6c3d15>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_cidades_venda.index, y=top_10_cidades_venda.values, palette='viridis')

# %% [markdown]
# ## Qual segmento teve maior total de vendas?

# %%
# ## Qual segmento teve maior total de vendas? (Gráfico de Pizza)
# %%
import matplotlib.pyplot as plt

# Agrupar por segmento e somar o valor de venda (usaremos o mesmo resultado anterior)
vendas_por_segmento = df.groupby('Segmento')['Valor_Venda'].sum()

# Criar o gráfico de pizza
plt.figure(figsize=(8, 8)) # Tamanho da figura (quadrada para um círculo)
plt.pie(vendas_por_segmento, labels=vendas_por_segmento.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(vendas_por_segmento))) # Usando seaborn para cores
plt.title('Proporção Total de Vendas por Segmento')
plt.axis('equal') # Garante que o gráfico de pizza seja um círculo.
plt.show()

# %% [markdown]
# ## Qual total de vendas por segmento e por ano?

# %%
# ## Qual o total de vendas por segmento e por ano?
# %%
# Converter a coluna 'Data_Pedido' para o tipo datetime, especificando o formato
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], format='%d/%m/%Y')

# Extrair o ano da data do pedido e criar uma nova coluna 'Ano'
df['Ano'] = df['Data_Pedido'].dt.year

# Agrupar por ano e segmento e somar o valor de venda
vendas_por_ano_segmento = df.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum().reset_index()

# Para visualizar o resultado
print("Total de vendas por ano e segmento:")
print(vendas_por_ano_segmento)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar o gráfico de linhas
plt.figure(figsize=(12, 7))
sns.lineplot(data=vendas_por_ano_segmento, x='Ano', y='Valor_Venda', hue='Segmento', marker='o')
plt.title('Total de Vendas por Ano e Segmento')
plt.xlabel('Ano')
plt.ylabel('Total de Vendas')
plt.xticks(vendas_por_ano_segmento['Ano'].unique()) # Define os ticks do eixo x nos anos únicos
plt.grid(True)
plt.legend(title='Segmento')
plt.show()
# Out:
# Total de vendas por ano e segmento:
#      Ano     Segmento  Valor_Venda
# 0   2015     Consumer  256719.9166
# 1   2015    Corporate  125819.5957
# 2   2015  Home Office   88229.0878
# 3   2016     Consumer  265295.2593
# 4   2016    Corporate  114643.1229
# 5   2016  Home Office   74134.1332
# 6   2017     Consumer  288459.5572
# 7   2017    Corporate  203266.7398
# 8   2017  Home Office  103639.6270
# 9   2018     Consumer  323359.6019
# 10  2018    Corporate  235502.7284
# 11  2018  Home Office  156488.5849

# %% [markdown]
# ## Quantas vendas receberiam 15% de desconto?

# %%
# ## Quantas vendas receberiam 15% de desconto (Hipótese)?
# %%
# **Hipótese:** Criando uma condição de exemplo: Vendas com Valor_Venda acima de 1000 receberiam 15% de desconto.
# Substitua esta lógica pela sua condição real de desconto.
desconto_condicao = df['Valor_Venda'] > 1000

# Criar uma nova coluna booleana indicando se a venda receberia desconto
df['Receberia_Desconto_15pct'] = desconto_condicao

# Contar o número de vendas que receberiam o desconto
total_vendas_desconto = df['Receberia_Desconto_15pct'].sum()

print(f"Número de vendas que receberiam 15% de desconto (sob a hipótese): {total_vendas_desconto}")

# %% [markdown]
# **Gráfico:** Para visualizar a proporção de vendas com e sem desconto, um gráfico de pizza ou um countplot são adequados. Vamos usar um countplot para mostrar as contagens.
# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Criar um countplot para mostrar a contagem de vendas com/sem desconto
plt.figure(figsize=(8, 5))
sns.countplot(x='Receberia_Desconto_15pct', data=df, hue='Receberia_Desconto_15pct', palette='viridis', legend=False) # Correção para evitar FutureWarning
plt.title('Distribuição de Vendas com e sem Desconto (Hipótese)')
plt.xlabel('Receberia 15% de Desconto')
plt.ylabel('Número de Vendas')
plt.xticks([False, True], ['Não', 'Sim']) # Define os rótulos do eixo x
plt.show()
# Out:
# Número de vendas que receberiam 15% de desconto (sob a hipótese): 457

# %% [markdown]
# ## Qual o media de vendas por segmento, por ano e por mes?

# %%
# ## Qual a média de vendas por segmento, por ano e por mês?
# %%
# Converter a coluna 'Data_Pedido' para o tipo datetime (se ainda não foi feito e corrigido o formato)
# Assumindo que o formato já foi corrigido para '%d/%m/%Y'
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], format='%d/%m/%Y')

# Extrair o ano e o mês da data do pedido e criar novas colunas
df['Ano'] = df['Data_Pedido'].dt.year
df['Mes'] = df['Data_Pedido'].dt.month

# Agrupar por ano, mês e segmento e calcular a média do valor de venda
media_vendas_por_periodo_segmento = df.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].mean().reset_index()

# Para visualizar o resultado
print("Média de vendas por ano, mês e segmento:")
print(media_vendas_por_periodo_segmento.head())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combinar Ano e Mês para um eixo x mais claro no gráfico
media_vendas_por_periodo_segmento['Ano_Mes'] = media_vendas_por_periodo_segmento['Ano'].astype(str) + '-' + media_vendas_por_periodo_segmento['Mes'].astype(str).str.zfill(2)

# Ordenar pelo Ano_Mes para garantir a ordem cronológica no gráfico
media_vendas_por_periodo_segmento = media_vendas_por_periodo_segmento.sort_values(by='Ano_Mes')

# Criar o gráfico de linhas
plt.figure(figsize=(15, 8))
sns.lineplot(data=media_vendas_por_periodo_segmento, x='Ano_Mes', y='Valor_Venda', hue='Segmento', marker='o', palette='viridis') # 'viridis' é uma paleta com cores vibrantes
plt.title('Média de Vendas por Período (Ano-Mês) e Segmento')
plt.xlabel('Período (Ano-Mês)')
plt.ylabel('Média do Valor de Venda')
plt.xticks(rotation=45, ha='right') # Rotação para melhor legibilidade dos rótulos de Ano-Mês
plt.grid(True)
plt.legend(title='Segmento')
plt.tight_layout() # Ajusta o layout
plt.show()
# Out:
# Média de vendas por ano, mês e segmento:
#     Ano  Mes     Segmento  Valor_Venda
# 0  2015    1     Consumer   146.736787
# 1  2015    1    Corporate   130.886769
# 2  2015    1  Home Office   329.855882
# 3  2015    2     Consumer   117.327926
# 4  2015    2    Corporate    69.235333

# %% [markdown]
# ## Qual o total de vendas por categoria e subcategoria, considerando somente as top 12 subcategorias?

# %%
# ## Gráfico de Anel para Proporção das Top 12 Subcategorias no Total de Vendas Delas
# %%
import matplotlib.pyplot as plt

# Certifique-se de que 'vendas_top_12_subcategorias' DataFrame está disponível
# (Ele foi criado nos passos anteriores)

# Calcular o total de vendas para cada uma das top 12 subcategorias
total_vendas_por_subcategoria_top12 = vendas_top_12_subcategorias.groupby('SubCategoria')['Valor_Venda'].sum()

# Criar o gráfico de anel
fig, ax = plt.subplots(figsize=(10, 10))

# Parâmetros para o gráfico de anel
outer_colors = sns.color_palette('viridis', len(total_vendas_por_subcategoria_top12))
inner_colors = sns.color_palette('viridis', len(total_vendas_por_subcategoria_top12)) # Podemos usar a mesma paleta

wedges, texts, autotexts = ax.pie(total_vendas_por_subcategoria_top12,
                                   autopct='%1.1f%%',
                                   pctdistance=0.85, # Distância do texto de porcentagem do centro
                                   startangle=90,
                                   colors=outer_colors,
                                   wedgeprops=dict(width=0.3, edgecolor='w')) # Configurações para o "anel"

# Desenhar um círculo no centro para criar o "anel"
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Legendas para as fatias
ax.legend(wedges, total_vendas_por_subcategoria_top12.index,
          title="Subcategorias",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

# Título
plt.title('Proporção do Total de Vendas entre as Top 12 Subcategorias')
plt.axis('equal')  # Garante que o gráfico de anel seja um círculo.
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-43-ccef73990296>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total_vendas_por_subcategoria_top12 = vendas_top_12_subcategorias.groupby('SubCategoria')['Valor_Venda'].sum()

# %%
# ## Gráfico de Anel Concêntrico (Categoria e Subcategoria - Top 12 Subcategorias) - Corrigido
# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np # Importar numpy para o posicionamento dos rótulos

# Certifique-se de que 'vendas_top_12_subcategorias' DataFrame está disponível
# (Ele foi criado nos passos anteriores e já contém as top 12 subcategorias e suas categorias)

# Ordenar as vendas_top_12_subcategorias para garantir que as fatias internas e externas se alinhem
# Isso é importante para o gráfico concêntrico. Primeiro por Categoria, depois por Subcategoria.
vendas_top_12_subcategorias_ordenado = vendas_top_12_subcategorias.sort_values(by=['Categoria', 'SubCategoria'])

# --- Início da Correção ---

# Calcular o total de vendas por Categoria (para o anel interno) a partir dos dados filtrados
# Use observed=True para seguir o futuro padrão e evitar o Future

total_vendas_por_categoria_top12 = vendas_top_12_subcategorias_ordenado.groupby('Categoria', observed=True)['Valor_Venda'].sum()

# Certificar-se de que total_vendas_por_categoria_top12 não está vazio
if total_vendas_por_categoria_top12.empty:
    print("Erro: Nenhum dado encontrado para as Categorias das Top 12 Subcategorias.")
else:
    # Calcular o total de vendas por Subcategoria (para o anel externo)
    # Use observed=True aqui também
    total_vendas_por_subcategoria_ordenado = vendas_top_12_subcategorias_ordenado.groupby(['Categoria', 'SubCategoria'], observed=True)['Valor_Venda'].sum()


    # --- Fim da Correção ---


    # Criar o gráfico
    fig, ax = plt.subplots(figsize=(12, 12))

    # Anel Interno (Categorias)
    size = 0.3 # Largura do anel
    outer_colors = sns.color_palette('viridis', len(total_vendas_por_categoria_top12)) # Cores para as categorias

    # Plotar o anel interno (Categorias)
    wedges, texts, autotexts = ax.pie(total_vendas_por_categoria_top12, radius=1, colors=outer_colors,
                                       wedgeprops=dict(width=size, edgecolor='w'), autopct='%1.1f%%', pctdistance=0.85, startangle=90) # Adicionado autopct, pctdistance, startangle aqui


    # Anel Externo (Subcategorias)
    # Precisamos alinhar as fatias do anel externo com as do interno.
    # Usaremos os valores da subcategoria, mas alinhados pela ordem da categoria.
    inner_colors = sns.color_palette('viridis', len(total_vendas_por_subcategoria_ordenado)) # Cores para as subcategorias (pode ser a mesma paleta ou diferente)
    wedges2, texts2, autotexts2 = ax.pie(total_vendas_por_subcategoria_ordenado, radius=1-size, colors=inner_colors,
                                          wedgeprops=dict(width=size, edgecolor='w'), autopct='%1.1f%%', pctdistance=0.85, startangle=90) # Adicionado autopct, pctdistance, startangle aqui


    # Adicionar rótulos de porcentagem ao anel interno (Categorias)
    # Posicionamos os rótulos no meio do anel interno
    for i, text in enumerate(autotexts):
        text.set_color('white') # Cor do texto (opcional)
        text.set_fontsize(10)    # Tamanho da fonte (opcional)
        # Para posicionar os rótulos: calculamos o ângulo da fatia e a distância do centro
        ang = (wedges[i].theta2 + wedges[i].theta1) / 2.
        y = 0.5 * np.cos(np.deg2rad(ang)) # Usando np.cos
        x = 0.5 * np.sin(np.deg2rad(ang)) # Usando np.sin
        # Ajuste o posicionamento com text.set_position((x, y)) se necessário

    # Adicionar rótulos de porcentagem ao anel externo (Subcategorias)
    # Posicionamos os rótulos no meio do anel externo
    for i, text in enumerate(autotexts2):
        text.set_color('black') # Cor do texto (opcional)
        text.set_fontsize(8)    # Tamanho da fonte (opcional)
        # Para posicionar os rótulos: calculamos o ângulo da fatia e a distância do centro
        ang = (wedges2[i].theta2 + wedges2[i].theta1) / 2.
        y = (1 - size/2) * np.cos(np.deg2rad(ang)) # Usando np.cos
        x = (1 - size/2) * np.sin(np.deg2rad(ang)) # Usando np.sin
        # Ajuste o posicionamento com text.set_position((x, y)) se necessário


    # Legendas
    # Criamos legendas separadas para as categorias (anel interno) e subcategorias (anel externo)
    legend_categories = ax.legend(wedges, total_vendas_por_categoria_top12.index,
                                  title="Categorias",
                                  loc="upper right",
                                  bbox_to_anchor=(1.1, 1))

    # Adicionamos a legenda das categorias ao gráfico
    ax.add_artist(legend_categories)

    # Legenda para as subcategorias (anel externo)
    legend_subcategories = ax.legend(wedges2, total_vendas_por_subcategoria_ordenado.index.get_level_values('SubCategoria'),
                                     title="Subcategorias",
                                     loc="lower right",
                                     bbox_to_anchor=(1.1, 0))

    # Título
    plt.title('Distribuição de Vendas por Categoria e Subcategoria (Top 12 Subcategorias)')
    plt.axis('equal')  # Garante que o gráfico seja um círculo.
    plt.tight_layout() # Ajusta o layout
    plt.show()
